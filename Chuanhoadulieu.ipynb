# %%
import pandas as pd

# %%
df = pd.read_excel('khuvuc.xlsx')

# %%
df_nguontintoipham = df.iloc[:,[0,1,2,3]]

dict_nguontintoipham = df_nguontintoipham.to_dict(orient='list')
print(dict_nguontintoipham)
# Out:
# {'Đơn vị': ['Khu vực 1 - An Giang', 'Khu vực 10 - An Giang', 'Khu vực 11 - An Giang', 'Khu vực 12 - An Giang', 'Khu vực 13 - An Giang', 'Khu vực 14 - An Giang', 'Khu vực 15 - An Giang', 'Khu vực 2 - An Giang', 'Khu vực 3 - An Giang', 'Khu vực 4 - An Giang', 'Khu vực 5 - An Giang', 'Khu vực 6 - An Giang', 'Khu vực 7 - An Giang', 'Khu vực 8 - An Giang', 'Khu vực 9 - An Giang', 'Khu vực 1 - Bắc Ninh', 'Khu vực 2 - Bắc Ninh', 'Khu vực 3 - Bắc Ninh', 'Khu vực 4 - Bắc Ninh', 'Khu vực 5 - Bắc Ninh', 'Khu vực 6 - Bắc Ninh', 'Khu vực 7 - Bắc Ninh', 'Khu vực 8 - Bắc Ninh', 'Khu vực 9 - Bắc Ninh', 'Khu vực 1 - Cao Bằng', 'Khu vực 2 - Cao Bằng', 'Khu vực 3 - Cao Bằng', 'Khu vực 4 - Cao Bằng', 'Khu vực 5 - Cao Bằng', 'Khu vực 1 - Cà Mau', 'Khu vực 2 - Cà Mau', 'Khu vực 3 - Cà Mau', 'Khu vực 4 - Cà Mau', 'Khu vực 5 - Cà Mau', 'Khu vực 6 - Cà Mau', 'Khu vực 7 - Cà Mau', 'Khu vực 8 - Cà Mau', 'Khu vực 9 - Cà Mau', 'Khu vực 1 - Cần Thơ', 'Khu vực 10 - Cần Thơ', 'Khu vực 11 - Cần Thơ', 'Khu vực 12 - C
# ...

# %%
df_andieutra = df.iloc[:,[0,1,2,3]]
dict_andieutra = df_andieutra.to_dict(orient='list')
print(dict_andieutra)
# Out:
# {'Tỉnh': ['An Giang', 'Bắc Ninh', 'Cà Mau', 'Cao Bằng', 'Cần Thơ', 'Đà Nẵng', 'Đắk Lắk', 'Điện Biên', 'Đồng Nai', 'Đồng Tháp', 'Gia Lai', 'Hà Nội', 'Hà Tĩnh', 'Hải Phòng', 'Hồ Chí Minh', 'Hưng Yên', 'Khánh Hòa', 'Lai Châu', 'Lạng Sơn', 'Lào Cai', 'Lâm Đồng', 'Nghệ An', 'Ninh Bình', 'Phú Thọ', 'Quảng Ngãi', 'Quảng Ninh', 'Quảng Trị', 'Sơn La', 'Tây Ninh', 'Thái Nguyên', 'Thanh Hoá', 'Huế', 'Tuyên Quang', 'Vĩnh Long'], 'Số cần nhập': [426, 378, 188, 473, 80, 430, 182, 66, 457, 222, 287, 2967, 121, 504, 53, 154, 355, 47, 965, 98, 147, 291, 369, 261, 168, 1951, 125, 80, 179, 235, 121, 96, 120, 179], 'Số mới nhập': [12, 0, 0, 0, 12, 99, 0, 5, 39, 0, 0, 103, 1, 1, 38, 0, 0, 11, 0, 0, 0, 3, 1, 0, 4, 0, 1, 0, 22, 2, 31, 15, 1, 1], 'Tổng đã nhập': [201, 99, 99, 93, 227, 721, 149, 81, 457, 84, 193, 1099, 7, 170, 410, 135, 265, 381, 66, 164, 176, 104, 116, 88, 164, 1979, 141, 69, 427, 53, 697, 286, 75, 192]}

# %%
df_anxetxu = df.iloc[:,[0,1,2,3]]
dict_anxetxu = df_anxetxu.to_dict(orient='list')
print(dict_anxetxu)
# Out:
# {'Tỉnh': ['An Giang', 'Bắc Ninh', 'Cà Mau', 'Cao Bằng', 'Cần Thơ', 'Đà Nẵng', 'Đắk Lắk', 'Điện Biên', 'Đồng Nai', 'Đồng Tháp', 'Gia Lai', 'Hà Nội', 'Hà Tĩnh', 'Hải Phòng', 'Hồ Chí Minh', 'Hưng Yên', 'Khánh Hòa', 'Lai Châu', 'Lạng Sơn', 'Lào Cai', 'Lâm Đồng', 'Nghệ An', 'Ninh Bình', 'Phú Thọ', 'Quảng Ngãi', 'Quảng Ninh', 'Quảng Trị', 'Sơn La', 'Tây Ninh', 'Thái Nguyên', 'Thanh Hoá', 'Huế', 'Tuyên Quang', 'Vĩnh Long'], 'Số cần nhập': [426, 378, 188, 473, 80, 430, 182, 66, 457, 222, 287, 2967, 121, 504, 53, 154, 355, 47, 965, 98, 147, 291, 369, 261, 168, 1951, 125, 80, 179, 235, 121, 96, 120, 179], 'Số mới nhập': [12, 0, 0, 0, 12, 99, 0, 5, 39, 0, 0, 103, 1, 1, 38, 0, 0, 11, 0, 0, 0, 3, 1, 0, 4, 0, 1, 0, 22, 2, 31, 15, 1, 1], 'Tổng đã nhập': [201, 99, 99, 93, 227, 721, 149, 81, 457, 84, 193, 1099, 7, 170, 410, 135, 265, 381, 66, 164, 176, 104, 116, 88, 164, 1979, 141, 69, 427, 53, 697, 286, 75, 192]}
